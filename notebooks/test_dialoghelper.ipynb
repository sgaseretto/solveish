# %% [markdown]
# # DialogHelper Integration Tests
#
# This notebook tests the dialoghelper integration with Dialeng, including:
# - Basic cell operations (read_msg, find_msgs, add_msg)
# - Cell content editing (msg_str_replace, msg_insert_line)
# - Cell properties (update_msg, pinned, skipped)
# - JavaScript injection via iife()
# - HTML injection via add_html()
# - Bidirectional data transfer (push_data/pop_data)
# - Cell execution via run_msg()
#
# **Run each cell in order to test the features.**

# %%
# Cell 1: Setup & Import
# Configure dialoghelper to connect to our server
from dialoghelper import dh_settings
dh_settings['port'] = 8000  # Dialeng server port

from dialoghelper import (
    read_msg, find_msgs, update_msg, add_msg, del_msg,
    msg_str_replace, msg_insert_line, msg_strs_replace, msg_replace_lines,
    msg_del_lines, copy_msg, paste_msg,
    add_html_a, iife_a, fire_event_a, event_get_a, run_msg,
    curr_dialog, msg_idx, toggle_comment
)
print("DialogHelper configured!")
print(f"Port: {dh_settings['port']}")

# %%
# Cell 2: Test curr_dialog - Get Dialog/Notebook Info
# Note: All dialoghelper functions are now async - use await
dialog = await curr_dialog()
print(f"Dialog name: {dialog['name']}")
print(f"Dialog mode: {dialog['mode']}")

# %%
# Cell 3: Test read_msg - Read Cell Content
# Note: read_msg() returns AttrDict - access via .type, .content, etc.
prev = await read_msg(-1)
print(f"Previous cell type: {prev.type}")
print(f"Previous cell content preview: {prev.content[:50]}...")

# Read current cell (n=0 means current)
current = await read_msg(0)
print(f"\nCurrent cell ID: {current.id}")
print(f"Current cell type: {current.type}")

# %%
# Cell 4: Test msg_idx - Get Cell Index
# Get the index of the setup cell
setup_idx = await msg_idx(id='setup')
print(f"Setup cell is at index: {setup_idx}")

# Get current cell index (access ID via .id)
current = await read_msg(0)
current_idx = await msg_idx(id=current.id)
print(f"Current cell is at index: {current_idx}")

# %%
# Cell 5: Test find_msgs - Search Cells
# Note: find_msgs returns list of dicts with 'content' field (not 'source')
code_cells = await find_msgs(msg_type="code", limit=10)
print(f"Found {len(code_cells)} code cells:")
for cell in code_cells[:5]:
    print(f"  - {cell.id}: {cell.content[:40]}...")

# Find cells matching a regex pattern
test_cells = await find_msgs(re_pattern="Test", limit=5)
print(f"\nFound {len(test_cells)} cells with 'Test' in content")

# %%
# Cell 6: Test update_msg - Update Cell Properties
# Get current cell
current = await read_msg(0)
print(f"Current cell ID: {current.id}")

# Pin the cell (keeps it in LLM context)
await update_msg(id=current.id, pinned=True)
print("Cell pinned!")

# Read back to verify
updated = await read_msg(0)
print(f"Pinned status: {updated.pinned}")

# Unpin it
await update_msg(id=current.id, pinned=False)
print("Cell unpinned!")

# %%
# Cell 7: Test add_msg - Create New Cells
# Note: add_msg returns just the cell ID string, not an object

# Add a note cell after this one
note_cell_id = await add_msg(
    "## Auto-generated Note\nThis note was created by Python code!",
    msg_type="note",
    placement="add_after"
)
print(f"Created note cell: {note_cell_id}")

# Add a code cell
code_cell_id = await add_msg(
    "# Auto-generated code cell\nprint('Hello from generated cell!')",
    msg_type="code",
    placement="add_after"
)
print(f"Created code cell: {code_cell_id}")

# %%
# Cell 8: Test msg_str_replace - Replace String in Cell
# First, create a cell to modify
test_cell_id = await add_msg(
    "Hello World! This is a TEST message.",
    msg_type="note",
    placement="add_after"
)
print(f"Created cell: {test_cell_id}")

# Read the cell to see original content
test_cell = await read_msg(id=test_cell_id)
print(f"Original: {test_cell.content}")

# Replace a string
await msg_str_replace(id=test_cell_id, old_str="World", new_str="Dialeng")

# Read back to verify
updated = await read_msg(id=test_cell_id)
print(f"After replace: {updated.content}")

# %%
# Cell 9: Test msg_insert_line - Insert Line in Cell
# Create a multi-line cell
test_cell_id = await add_msg(
    "Line 1\nLine 2\nLine 3",
    msg_type="note",
    placement="add_after"
)
print(f"Created cell: {test_cell_id}")

# Read the cell to see original content
test_cell = await read_msg(id=test_cell_id)
print(f"Original:\n{test_cell.content}")

# Insert a line after line 1 (0-indexed)
await msg_insert_line(id=test_cell_id, insert_line=1, new_str="Inserted Line!")

# Read back to verify
updated = await read_msg(id=test_cell_id)
print(f"\nAfter insert:\n{updated.content}")

# %%
# Cell 10: Test del_msg - Delete Cell
# Create a temporary cell
temp_cell_id = await add_msg(
    "This cell will be deleted",
    msg_type="note",
    placement="add_after"
)
print(f"Created cell: {temp_cell_id}")

# Count cells before
cells_before = await find_msgs(limit=100)
print(f"Cells before deletion: {len(cells_before)}")

# Delete the cell
await del_msg(id=temp_cell_id)
print("Cell deleted!")

# Count cells after
cells_after = await find_msgs(limit=100)
print(f"Cells after deletion: {len(cells_after)}")

# %% [markdown]
# ## JavaScript Injection Tests (iife)
#
# The following cells test `iife()` which allows executing JavaScript in the browser from Python.

# %%
# Cell 11: Test iife - Console Log
# Simple console.log to verify JS injection works
await iife_a("console.log('Hello from Python via iife!')")
print("Check browser console (F12 > Console) for the message!")

# %%
# Cell 12: Test iife - Alert Box
# Simple alert to verify JS injection works
await iife_a("alert('Hello from Python via iife!')")
print("Alert triggered! Check for popup.")

# %%
# Cell 13: Test iife - DOM Manipulation
# Change page background color temporarily
await iife_a("""
    const original = document.body.style.backgroundColor;
    document.body.style.backgroundColor = '#e8f5e9';  // Light green
    setTimeout(() => {
        document.body.style.backgroundColor = original;
    }, 2000);
    console.log('Background changed for 2 seconds');
""")
print("Check the page - background should flash green!")

# %%
# Cell 14: Test iife - Add Custom UI Element
# Inject a floating notification
await iife_a("""
    const notif = document.createElement('div');
    notif.id = 'test-notification';
    notif.style.cssText = `
        position: fixed;
        top: 20px;
        right: 20px;
        padding: 15px 25px;
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        color: white;
        border-radius: 8px;
        box-shadow: 0 4px 15px rgba(0,0,0,0.2);
        z-index: 10000;
        font-family: system-ui;
    `;
    notif.textContent = 'Injected from Python!';
    document.body.appendChild(notif);
    setTimeout(() => notif.remove(), 3000);
""")
print("Look at the top-right corner!")

# %%
# Cell 15: Test add_html - Direct HTML Injection
# Inject HTML with HTMX OOB swap
await add_html_a('''
<div hx-swap-oob="beforeend:#ephemeral">
    <script>
        console.log('Script injected via add_html!');
        const banner = document.createElement('div');
        banner.style.cssText = 'padding: 10px; margin: 10px 0; background: #d4edda; border-radius: 4px; border: 1px solid #c3e6cb;';
        banner.textContent = 'This banner was injected via add_html()!';
        document.getElementById('ephemeral').appendChild(banner);
    </script>
</div>
''')
print("HTML/Script injected! Check for green banner at bottom of page.")

# %% [markdown]
# ## Bidirectional Data Transfer Tests
#
# The following cells test the bidirectional communication between Python and JavaScript.

# %%
# Cell 16: Test Bidirectional Data Transfer - Setup Event Listener
# Set up listener via iife to respond to events
await iife_a("""
    // Remove any existing listener first
    if (window._browserInfoHandler) {
        document.body.removeEventListener('get-browser-info', window._browserInfoHandler);
    }
    
    window._browserInfoHandler = (e) => {
        const data = {
            url: window.location.href,
            title: document.title,
            timestamp: new Date().toISOString(),
            viewport: {
                width: window.innerWidth,
                height: window.innerHeight
            }
        };
        // Push data back to Python
        fetch('/push_data_blocking_', {
            method: 'POST',
            headers: {'Content-Type': 'application/x-www-form-urlencoded'},
            body: `dlg_name=${window.NOTEBOOK_ID}&data_id=${e.detail.idx}&data=${JSON.stringify(data)}`
        });
    };
    document.body.addEventListener('get-browser-info', window._browserInfoHandler);
    console.log('Event listener registered for get-browser-info');
""")
print("Event listener set up!")

# %%
# Cell 17: Trigger Event and Get Response
# This fires an event and waits for the JS listener to respond
try:
    result = await event_get_a('get-browser-info', timeout=5)
    print("Received from browser:")
    print(f"  URL: {result.url}")
    print(f"  Title: {result.title}")
    print(f"  Viewport: {result.viewport.width}x{result.viewport.height}")
except Exception as e:
    print(f"Error: {e}")
    print("Make sure you ran the event setup cell first!")

# %% [markdown]
# ## Cell Execution Tests
#
# The following cells test programmatic cell execution via `run_msg()`.

# %%
# Cell 18: Test run_msg - Queue Cell for Execution
import time

# Create a code cell that will produce output
code_cell_id = await add_msg(
    "result = 2 + 2\nprint(f'The answer is {result}')\nresult",
    msg_type="code",
    placement="add_after"
)
print(f"Created code cell: {code_cell_id}")

# Queue the cell for execution
await run_msg(code_cell_id)
print("Cell queued for execution...")

# Wait for execution to complete
time.sleep(2)

# Read the cell to see its output
result = await read_msg(id=code_cell_id)
print(f"\nCell output after execution:")
print(f"  Content: {result.content}")
print(f"  Output: {result.output if hasattr(result, 'output') else 'N/A'}")

# %% [markdown]
# ## New DialogHelper v2 Features
#
# The following cells test features added in the dialoghelper v2 update.

# %%
# Cell 19: Test msg_del_lines - Delete Line Range
test_cell_id = await add_msg(
    "Line 1\nLine 2 - delete me\nLine 3 - delete me\nLine 4\nLine 5",
    msg_type="note",
    placement="add_after"
)
original = await read_msg(id=test_cell_id)
print(f"Original:\n{original.content}")

# Delete lines 2-3 (1-based indexing)
await msg_del_lines(id=test_cell_id, start_line=2, end_line=3)

updated = await read_msg(id=test_cell_id)
print(f"\nAfter deleting lines 2-3:\n{updated.content}")

# Clean up
await del_msg(id=test_cell_id)

# %%
# Cell 20: Test copy_msg / paste_msg - Clipboard Operations
# Create a cell to copy
src_id = await add_msg(
    "# This cell will be copied\nprint('Original content')",
    msg_type="code",
    placement="add_after"
)
print(f"Created source cell: {src_id}")

# Copy the cell
await copy_msg(ids=src_id)
print("Cell copied to clipboard!")

# Paste after current cell
current = await read_msg(0)
await paste_msg(id=current.id, after=True)
print("Cell pasted!")

# Verify
cells = await find_msgs(re_pattern="This cell will be copied", limit=5)
print(f"Found {len(cells)} cells with 'This cell will be copied'")

# Clean up
for c in cells:
    await del_msg(id=c.id)

# %%
# Cell 21: Test toggle_comment - Toggle Code Comments
test_cell_id = await add_msg(
    "x = 1\ny = 2\nresult = x + y\nprint(result)",
    msg_type="code",
    placement="add_after"
)
original = await read_msg(id=test_cell_id)
print(f"Original:\n{original.content}")

# Toggle comments on
await toggle_comment(id=test_cell_id)
commented = await read_msg(id=test_cell_id)
print(f"\nAfter commenting:\n{commented.content}")

# Toggle comments off
await toggle_comment(id=test_cell_id)
uncommented = await read_msg(id=test_cell_id)
print(f"\nAfter uncommenting:\n{uncommented.content}")

# Clean up
await del_msg(id=test_cell_id)

# %%
# Cell 22: Test find_msgs with new v2 params
# Test case-sensitive search - use "Cell" which appears capitalized in comments
# but rarely lowercase, so case sensitivity should show a difference
results = await find_msgs(re_pattern="Cell", use_case=False, limit=20)
print(f"Case-insensitive 'Cell': {len(results)} results")

results_cs = await find_msgs(re_pattern="Cell", use_case=True, limit=20)
print(f"Case-sensitive 'Cell': {len(results_cs)} results")

# These should differ if use_case works (case-insensitive catches "cell" too)
assert len(results) >= len(results_cs), "Case-insensitive should find >= case-sensitive"
print(f"  -> Difference: {len(results) - len(results_cs)} extra from case-insensitive")

# Test literal (non-regex) search
results_lit = await find_msgs(re_pattern=".*", use_regex=False, limit=5)
print(f"\nLiteral '.*' search: {len(results_lit)} results")

results_re = await find_msgs(re_pattern=".*", use_regex=True, limit=50)
print(f"Regex '.*' search: {len(results_re)} results (matches everything)")
assert len(results_re) > len(results_lit), "Regex .* should match far more than literal .*"

# Test finding only code cells
code_cells = await find_msgs(msg_type="code", limit=5)
print(f"\nCode cells: {len(code_cells)}")
print("find_msgs v2 params working!")

# %% [markdown]
# ## Summary
#
# If all cells ran successfully, you've verified:
#
# ### Basic Operations
# - **curr_dialog()** - Get dialog/notebook info (returns plain dict)
# - **read_msg()** - Read cell content (returns AttrDict with .id, .source, etc.)
# - **msg_idx()** - Get cell index by ID
# - **find_msgs()** - Search cells by type, pattern, etc. (returns list of AttrDicts)
#
# ### Cell Modification
# - **add_msg()** - Create new cells (returns cell ID string)
# - **del_msg()** - Delete cells
# - **update_msg()** - Update cell properties (pinned, skipped, etc.)
# - **msg_str_replace()** - Replace string in cell
# - **msg_insert_line()** - Insert line in cell
#
# ### JavaScript Integration
# - **iife_a()** - Execute JavaScript in browser (async version of iife)
# - **add_html_a()** - Inject HTML via HTMX OOB (async version of add_html)
#
# ### Bidirectional Communication
# - **fire_event_a()** - Fire browser events from Python (async)
# - **event_get_a()** - Request/response pattern with browser (async)
#
# ### Execution
# - **run_msg()** - Queue cells for execution
#
# ### New v2 Features
# - **msg_del_lines()** - Delete line range with optional regex filter
# - **copy_msg() / paste_msg()** - Clipboard operations
# - **toggle_comment()** - Toggle line comments on code cells
# - **find_msgs()** v2 params - case sensitivity, regex toggle, error/export/changed filters
#
# **Important:** All dialoghelper functions are now async - use `await` on every call. For JS injection functions, use the `_a` variants: `iife_a`, `add_html_a`, `fire_event_a`, `event_get_a`.
