# %% [markdown]
# ## Project Context
#
# This is the **Demo Project**. All notebooks in this folder and subfolders share this context.
#
# Key conventions:
# - Use `print()` for output, not bare expressions
# - Import helpers from dialoghelper when needed
# - Follow PEP 8 style

# %%
# CRAFT auto-setup: show banner and configure environment
from dialoghelper import iife_a, dh_settings
dh_settings['port'] = 8000

await iife_a("""
    const banner = document.createElement('div');
    banner.id = 'craft-banner-start';
    banner.style.cssText = 'position:fixed;top:0;left:0;right:0;padding:8px 16px;background:linear-gradient(90deg,#2563eb,#7c3aed);color:white;text-align:center;font-size:13px;z-index:9999;transition:opacity 0.5s';
    banner.textContent = '\u2699\ufe0f CRAFT loading: Setting up project environment...';
    document.body.prepend(banner);
""")
print('[CRAFT] Project environment setup started')
# Out:
# [CRAFT] Project environment setup started

# %%
# CRAFT auto-setup: shared imports and config
import json
from pathlib import Path
from datetime import datetime
import time

PROJECT_NAME = 'Demo Project'
PROJECT_START = datetime.now().isoformat()
print(f'[CRAFT] {PROJECT_NAME} initialized at {PROJECT_START}')
time.sleep(1)
# Out:
# [CRAFT] Demo Project initialized at 2026-03-12T01:29:43.894090

# %%
# CRAFT auto-setup: show completion banner
await iife_a("""
    const banner = document.getElementById('craft-banner-start');
    if (banner) {
        banner.textContent = '\u2705 CRAFT loaded: Project environment ready!';
        banner.style.background = 'linear-gradient(90deg, #059669, #2563eb)';
        setTimeout(() => { banner.style.opacity = '0'; setTimeout(() => banner.remove(), 500); }, 3000);
    }
""")
print('[CRAFT] Project environment setup complete')
# Out:
# [CRAFT] Project environment setup complete
