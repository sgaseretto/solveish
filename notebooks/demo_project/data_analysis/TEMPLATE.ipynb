# %% [markdown]
# ## Data Analysis Section
#
# > *This section was added by `data_analysis/TEMPLATE.ipynb`*
#
# The data science stack (numpy, pandas, matplotlib) is auto-imported by CRAFT.
# Use the cells below to start your analysis.

# %%
# Starter cell from data_analysis/TEMPLATE
# The data science stack was auto-imported by CRAFT
print('Data analysis notebook ready')
print(f'numpy version: {np.__version__}')
