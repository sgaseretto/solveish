# %% [markdown]
# ## Data Analysis Context
#
# Notebooks in this folder focus on **data analysis**.
# Use pandas, matplotlib, and numpy for data work.
# Always include axis labels and titles on plots.

# %%
# Data analysis CRAFT: import standard data science stack
import numpy as np
try:
    import pandas as pd
    print('[CRAFT] pandas loaded')
except ImportError:
    print('[CRAFT] pandas not available, install with: pip install pandas')

try:
    import matplotlib.pyplot as plt
    plt.style.use('ggplot')
    print('[CRAFT] matplotlib loaded with ggplot style')
except ImportError:
    print('[CRAFT] matplotlib not available')
